# %%
from OneMaxExperiments import main

# %% [markdown]
# ## Размер популяции и количество поколений

# %%
main(ps=200, pc=0.9, pm=0.1)

# %%
main(ps=400, pc=0.9, pm=0.1)

# %%
main(ps=100, pc=0.9, pm=0.1, ngen=100)

# %%
main(ps=100, pc=0.9, pm=0.9)

# %% [markdown]
# ## Оператор мутации

# %%
main(ps=100, pc=0.9, pm=0.9, indpb=10)

# %%
main(ps=100, pc=0.9, pm=0.9, indpb=50)
